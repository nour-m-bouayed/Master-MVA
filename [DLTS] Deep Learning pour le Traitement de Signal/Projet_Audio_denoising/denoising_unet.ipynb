# %% [markdown]
# <h2>Read and play the signals</h2>
#
# <h3 color='g'>Question<h3>
# --- why the sampling frequency not the same when I read a signal using scipy and librosa???

# %%
import numpy as np
import matplotlib.pylab as plt
import scipy
import librosa
import librosa.display
from IPython.core.display import display
import IPython.display as ipd
from data import create_spec
import os
import torch
from torch import nn
from args import config
args= config()
# Out:
# C:\Users\imane\AppData\Local\Temp\ipykernel_34020\4093833801.py:6: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display

# %%
sig_noisy_path= "data/train_small/noisy/signal/Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_0_.wav"
sig_path= "data/train_small/original/signal/Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_0_.wav"

fs_noisy, sig_noisy = scipy.io.wavfile.read(sig_noisy_path)
fs, sig = scipy.io.wavfile.read(sig_path)

print("noisy singnal:")
display(ipd.Audio(data= sig_noisy, rate= fs))
print("original signal:")
display(ipd.Audio(data= sig, rate=fs))
# Out:
# noisy singnal:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# original signal:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sign= librosa.load(sig_path)

signal, fs= sign

# %%
print('teh shape of the original signal is: {}'.format(sig.shape))
print(" the sampling frequency is: {}".format(fs))
# Out:
# teh shape of the original signal is: (80000,)
#  the sampling frequency is: 8000

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,1,1)
plt.plot(sig, label='orginal signal')
plt.title('Original signal')

plt.subplot(2,1,2)
plt.plot(sig_noisy)
plt.title("noisy singal")
plt.show()

# %% [markdown]
# <h2>Get the spectrograms and visualze:

# %%
#get stft
stft_noisy= librosa.stft(sig_noisy.astype(float))
stft_origin= librosa.stft(sig.astype(float))
# get the mel
# mel_noisy= librosa.feature.melspectrogram(y=sig_noisy.astype(float), sr= fs_noisy)
# mel_origin= librosa.feature.melspectrogram(y=sig.astype(float), sr= fs)


# Displaying the results
fig, ax = plt.subplots(1, 2, figsize=(15, 10))

librosa.display.specshow(librosa.amplitude_to_db(abs(stft_noisy)),
                         sr=fs_noisy, x_axis='time', y_axis='log', ax=ax[0], cmap='viridis')
ax[0].set_title('STFT of Noisy Signal')
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Frequency')

librosa.display.specshow(librosa.amplitude_to_db(abs(stft_origin)),
                         sr=fs, x_axis='time', y_axis='log', ax=ax[1], cmap='viridis')
ax[1].set_title('STFT of Original Signal')
ax[1].set_xlabel('Time')
ax[1].set_ylabel('Frequency')

# librosa.display.specshow(librosa.power_to_db(mel_noisy),
#                          sr=fs_noisy, x_axis='time', y_axis='mel', ax=ax[1, 0], cmap='viridis')
# ax[1, 0].set_title('Mel Spectrogram of Noisy Signal')
# ax[1, 0].set_xlabel('Time')
# ax[1, 0].set_ylabel('Mel')

# librosa.display.specshow(librosa.power_to_db(mel_origin),
#                          sr=fs_noisy, x_axis='time', y_axis='mel', ax=ax[1, 1], cmap='viridis')
# ax[1, 1].set_title('Mel Spectrogram of Origin Signal')
# ax[1, 1].set_xlabel('Time')
# ax[1, 1].set_ylabel('Mel')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #get stft
# ----> 2 stft_noisy= librosa.stft(sig_noisy.astype(float))
#       3 stft_origin= librosa.stft(sig.astype(float))
#       4 # get the mel
#       5 # mel_noisy= librosa.feature.melspectrogram(y=sig_noisy.astype(float), sr= fs_noisy)
#       6 # mel_origin= librosa.feature.melspectrogram(y=sig.astype(float), sr= fs)
#       7
#       8
#       9 # Displaying the results
#
# NameError: name 'sig_noisy' is not defined

# %% [markdown]
# We can clearly differentiate between some features of the original signal and noisy signal

# %%
# ## store the spectrogram images
# signals_path='data/train'
# n_fft= args.n_fft
# hop_length_fft= args.hop_length_fft
# create_spec(signals_path, n_fft,hop_length_fft, noisy=False)
# Out:
# original
# Spectrograms and phases stored in 'data/train\original\spec' and 'data/train\original\phase' respectively.

# %%
import os
files= os.listdir('data/train/noisy/signal/')
print('nb files:', len(files))
spec= os.listdir('data/train/noisy/phase/')
print('nb spec:', len(spec))
# Out:
# nb files: 2118
# nb spec: 2118

# %%
#after creating spec and phase retreive the audio signal
from data import retreive_sig
from PIL import Image
path_spec='data/train_small/original/spec/Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_0_.wav.npy'
path_phase= 'data/train_small/original/phase/Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_0_.wav.npy'
spec= np.load(path_spec)
plt.imshow(spec)
plt.title("spec of signal to be retreived")
phase= np.load(path_phase)
# plt.imshow(spec)
print(spec.shape)
fs= 8000
audio_retrieved= retreive_sig(spec, phase, args.n_fft, args.hop_length_fft)
plt.figure(figsize=(10,4))
plt.plot(audio_retrieved)
plt.title('retreived signal')
plt.show()

display(ipd.Audio(data= audio_retrieved, rate= fs))
print(audio_retrieved.shape)
# Out:
# (257, 313)
# after includind the phase (257, 313)
# befooore audio (79872,)
# retreived audia shape: (79872,)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# (79872,)

# %% [markdown]
# <h2>Train baseline model</h2>

# %%
import torch
from model import My_unet
x= torch.rand(1,1,256,256)

print(x.shape)

model= My_unet(1,5)

out= model(x)
# cov1 , down1= out
print(out.shape)
# print(cov1.shape)
# print(down1.shape)
# Out:
# torch.Size([1, 1, 256, 256])
# torch.Size([1, 5, 256, 256])

# %%
path_phase.split('.')[0]
# Out:
# 'data/train_small/original/phase/Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_4_'

# %%
# create dataset class and get data
from torchvision import transforms
from data import MyDataset
from train_unet import get_pesq, get_stoi
from torch.utils.data import DataLoader, random_split


path= 'data/train_small/'

transform= transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

dataset= MyDataset(path, transform=transform)
train_set, val_set= random_split(dataset, [0.81, 0.19])
# data loader
train_loader= DataLoader(dataset, batch_size= 1, shuffle= True)
val_loader= DataLoader(dataset, batch_size= 1, shuffle= True)


# write train loop 
for i, data in enumerate(train_loader):
    noisy_spec_val, original_spec_val,  noisy_phase_val, original_singal_val = data
    # print(type(ori))
    print(noisy_spec_val.shape)
    print(original_singal_val[1].shape)
    resize_spec= transforms.Resize((args.height, args.width))
    r= resize_spec(noisy_spec_val)
    # print(r)
    a= get_stoi(original_singal_val, noisy_spec_val, noisy_phase_val)
    print(a)
    # suppoose I want to see the effect of the noise
    break
#visualize the output of the unet
# Out:
# torch.Size([1, 1, 256, 256])
# torch.Size([1, 80000])
# c:\Users\imane\MVA\Apprentissage profond et traitement du signal, introduction et applications industrielles\Projet\.venv\lib\site-packages\torchvision\transforms\functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# 0.8936187028884888

# %%
#bluid train loop 
from torch import nn
from train_unet import train
from model import My_unet

model= My_unet(in_channels=1, out_channels=1)

nepochs= 5
batch_size= 1
train_losses, val_losses, val_pesq_scores, val_stoi_scores= train(model, data_path='data/train_small/', batch_size= batch_size, n_epochs= nepochs, transform=transform, save_path=None)

# Plot training and validation losses
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
plt.plot(val_pesq_scores, label='PESQ')
plt.plot(val_stoi_scores, label='STOI')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('PESQ and STOI')
plt.legend()
plt.show()
# Out:
# Loading the data...
# Device: cpu
#
#  start training
#   0%|          | 0/5 [00:00<?, ?it/s]c:\Users\imane\MVA\Apprentissage profond et traitement du signal, introduction et applications industrielles\Projet\.venv\lib\site-packages\torchvision\transforms\functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
#  20%|██        | 1/5 [00:07<00:31,  7.93s/it]
# after includind the phase (1, 1, 257, 313)
# befooore audio (1, 1, 79872)
# retreived audia shape: (1, 80000)
# after includind the phase (1, 1, 257, 313)
# befooore audio (1, 1, 79872)
# retreived audia shape: (1, 80000)
# Epoch 1, Train Loss: 7305.1593, Validation Loss: 4305.5425, Average PESQ: 1.2562, Average STOI: 0.4461
#  40%|████      | 2/5 [00:16<00:25,  8.49s/it]
# after includind the phase (1, 1, 257, 313)
# befooore audio (1, 1, 79872)
# retreived audia shape: (1, 80000)
# after includind the phase (1, 1, 257, 313)
# befooore audio (1, 1, 79872)
# retreived audia shape: (1, 80000)
# Epoch 2, Train Loss: 4314.6264, Validation Loss: 3042.2886, Average PESQ: 1.3128, Average STOI: 0.4952
#  60%|██████    | 3/5 [00:25<00:16,  8.48s/it]
# after includind the phase (1, 1, 257, 313)
# befooore audio (1, 1, 79872)
# retreived audia shape: (1, 80000)
# after includind the phase (1, 1, 257, 313)
# befooore audio (1, 1, 79872)
# retreived audia shape: (1, 80000)
# Epoch 3, Train Loss: 3272.6882, Validation Loss: 2981.2588, Average PESQ: 1.1947, Average STOI: 0.5080
#  80%|████████  | 4/5 [00:33<00:08,  8.57s/it]
# after includind the phase (1, 1, 257, 313)
# befooore audio (1, 1, 79872)
# retreived audia shape: (1, 80000)
# after includind the phase (1, 1, 257, 313)
# befooore audio (1, 1, 79872)
# retreived audia shape: (1, 80000)
# Epoch 4, Train Loss: 1943.2231, Validation Loss: 498.9194, Average PESQ: 1.3403, Average STOI: 0.6285
# 100%|██████████| 5/5 [00:41<00:00,  8.31s/it]
# after includind the phase (1, 1, 257, 313)
# befooore audio (1, 1, 79872)
# retreived audia shape: (1, 80000)
# after includind the phase (1, 1, 257, 313)
# befooore audio (1, 1, 79872)
# retreived audia shape: (1, 80000)
# Epoch 5, Train Loss: 461.5101, Validation Loss: 318.6161, Average PESQ: 1.6187, Average STOI: 0.6605

# %%
# test the model:
from torch import nn
from test_unet import test
from model import My_unet

model= My_unet(in_channels=1, out_channels=1)

nepochs= 5
batch_size= 1
average_test_loss, average_pesq_score, average_stoi_score= test(model, data_path='data/train_small/', batch_size= batch_size, transform=transform, save_path=None)
# Out:
# Loading the data...
# Device: cpu
# c:\Users\imane\MVA\Apprentissage profond et traitement du signal, introduction et applications industrielles\Projet\.venv\lib\site-packages\torchvision\transforms\functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Test Loss: 4452.4444, Average PESQ: 1.2489, Average STOI: 0.4240

# %%
import os

# Define the directory containing the files
directory = 'data/train/original/spec'

# Iterate over all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".wav.npy"):
        # Construct the old file path
        old_file = os.path.join(directory, filename)

        # Construct the new file name by removing '.wav'
        new_filename = filename.replace('.wav', '')

        # Construct the new file path
        new_file = os.path.join(directory, new_filename)

        # Rename the file
        os.rename(old_file, new_file)
        print(f"Renamed '{old_file}' to '{new_file}'")
# Out:
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_0_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_0_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_10_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_10_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_11_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_11_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_12_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_12_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_13_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_13_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_14_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_14_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_15_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_15_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_16_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_16_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_17_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_17_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_18_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_18_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_19_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_19_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_1_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_1_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_20_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_20_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_21_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_21_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_22_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_22_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_23_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_23_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_24_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_24_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_25_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_25_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_26_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_26_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_27_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_27_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_28_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_28_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_29_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_29_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_2_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_2_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_30_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_30_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_31_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_31_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_32_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_32_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_33_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_33_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_34_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_34_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_35_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_35_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_36_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_36_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_37_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_37_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_38_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_38_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_39_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_39_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_3_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_3_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_40_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_40_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_41_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_41_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_42_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_42_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_43_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_43_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_44_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_44_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_45_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_45_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_46_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_46_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_47_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_47_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_48_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_48_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_49_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_49_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_4_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_4_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_50_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_50_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_51_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_51_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_52_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_52_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_53_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_53_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_54_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_54_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_55_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_55_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_56_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_56_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_57_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_57_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_58_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_58_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_59_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_59_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_5_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_5_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_60_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_60_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_61_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_61_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_62_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_62_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_63_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_63_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_64_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_64_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_65_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_65_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_66_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_66_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_67_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_67_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_68_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_68_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_69_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_69_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_6_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_6_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_70_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_70_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_71_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_71_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_72_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_72_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_73_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_73_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_74_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_74_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_75_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_75_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_76_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_76_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_77_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_77_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_78_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_78_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_79_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_79_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_7_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_7_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_80_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_80_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_81_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_81_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_82_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_82_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_83_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_83_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_8_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_8_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_9_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap01_9_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_0_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_0_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_100_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_100_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_101_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_101_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_102_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_102_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_103_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_103_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_104_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_104_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_105_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_105_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_106_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_106_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_107_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_107_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_108_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_108_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_109_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_109_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_10_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_10_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_110_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_110_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_111_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_111_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_112_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_112_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_113_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_113_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_114_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_114_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_115_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_115_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_116_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_116_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_117_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_117_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_118_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_118_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_119_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_119_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_11_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_11_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_120_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_120_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_121_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_121_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_122_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_122_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_123_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_123_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_124_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_124_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_125_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_125_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_126_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_126_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_127_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_127_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_128_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_128_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_129_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_129_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_12_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_12_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_130_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_130_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_131_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_131_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_132_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_132_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_133_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_133_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_134_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_134_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_135_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_135_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_136_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_136_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_137_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_137_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_138_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_138_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_139_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_139_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_13_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_13_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_140_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_140_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_141_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_141_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_142_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_142_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_143_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_143_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_144_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_144_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_145_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_145_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_146_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_146_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_147_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_147_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_148_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_148_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_149_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_149_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_14_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_14_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_150_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_150_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_151_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_151_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_152_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_152_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_153_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_153_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_154_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_154_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_155_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_155_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_156_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_156_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_15_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_15_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_16_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_16_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_17_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_17_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_18_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_18_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_19_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_19_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_1_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_1_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_20_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_20_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_21_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_21_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_22_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_22_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_23_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_23_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_24_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_24_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_25_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_25_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_26_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_26_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_27_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_27_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_28_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_28_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_29_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_29_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_2_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_2_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_30_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_30_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_31_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_31_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_32_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_32_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_33_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_33_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_34_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_34_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_35_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_35_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_36_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_36_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_37_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_37_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_38_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_38_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_39_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_39_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_3_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_3_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_40_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_40_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_41_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_41_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_42_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_42_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_43_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_43_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_44_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_44_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_45_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_45_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_46_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_46_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_47_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_47_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_48_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_48_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_49_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_49_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_4_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_4_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_50_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_50_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_51_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_51_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_52_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_52_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_53_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_53_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_54_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_54_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_55_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_55_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_56_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_56_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_57_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_57_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_58_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_58_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_59_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_59_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_5_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_5_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_60_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_60_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_61_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_61_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_62_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_62_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_63_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_63_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_64_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_64_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_65_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_65_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_66_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_66_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_67_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_67_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_68_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_68_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_69_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_69_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_6_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_6_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_70_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_70_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_71_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_71_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_72_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_72_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_73_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_73_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_74_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_74_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_75_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_75_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_76_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_76_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_77_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_77_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_78_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_78_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_79_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_79_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_7_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_7_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_80_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_80_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_81_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_81_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_82_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_82_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_83_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_83_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_84_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_84_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_85_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_85_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_86_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_86_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_87_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_87_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_88_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_88_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_89_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_89_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_8_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_8_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_90_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_90_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_91_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_91_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_92_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_92_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_93_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_93_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_94_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_94_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_95_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_95_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_96_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_96_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_97_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_97_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_98_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_98_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_99_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_99_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_9_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap02_9_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_0_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_0_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_100_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_100_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_101_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_101_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_102_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_102_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_103_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_103_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_104_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_104_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_105_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_105_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_106_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_106_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_107_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_107_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_108_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_108_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_109_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_109_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_10_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_10_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_110_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_110_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_111_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_111_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_112_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_112_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_113_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_113_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_114_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_114_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_115_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_115_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_116_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_116_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_117_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_117_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_118_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_118_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_119_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_119_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_11_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_11_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_120_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_120_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_121_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_121_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_122_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap04_122_.npy'
# ...
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_1_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_1_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_20_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_20_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_21_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_21_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_22_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_22_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_23_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_23_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_24_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_24_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_25_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_25_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_26_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_26_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_27_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_27_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_28_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_28_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_29_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_29_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_2_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_2_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_30_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_30_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_31_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_31_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_32_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_32_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_33_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_33_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_34_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_34_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_35_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_35_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_36_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_36_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_37_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_37_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_38_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_38_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_39_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_39_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_3_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_3_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_40_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_40_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_41_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_41_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_42_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_42_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_43_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_43_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_44_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_44_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_45_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_45_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_46_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_46_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_47_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_47_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_48_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_48_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_49_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_49_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_4_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_4_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_50_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_50_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_51_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_51_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_52_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_52_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_53_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_53_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_54_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_54_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_55_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_55_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_56_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_56_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_57_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_57_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_58_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_58_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_59_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_59_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_5_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_5_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_60_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_60_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_61_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_61_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_62_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_62_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_63_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_63_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_64_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_64_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_65_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_65_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_66_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_66_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_67_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_67_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_68_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_68_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_69_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_69_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_6_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_6_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_70_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_70_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_71_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_71_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_72_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_72_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_73_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_73_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_74_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_74_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_75_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_75_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_76_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_76_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_77_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_77_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_78_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_78_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_79_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_79_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_7_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_7_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_80_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_80_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_81_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_81_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_82_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_82_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_83_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_83_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_84_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_84_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_85_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_85_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_86_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_86_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_87_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_87_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_88_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_88_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_89_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_89_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_8_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_8_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_90_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_90_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_91_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_91_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_92_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_92_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_93_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_93_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_94_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_94_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_95_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_95_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_96_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_96_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_97_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_97_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_98_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_98_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_99_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_99_.npy'
# Renamed 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_9_.wav.npy' to 'data/train/original/spec\Jules_Verne_-_L_ile_mysterieuse_Partie1_Chap22_9_.npy'
